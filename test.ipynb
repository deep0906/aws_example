# %%
from flask import Flask, render_template, request, flash, redirect
import nltk
from nltk.tokenize import RegexpTokenizer,word_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize
import re
import string
import os
import pandas as pd
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Adi\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
with open('AliceCleaner.txt','r', encoding="utf8") as f:
    content = f.read()

# df1=pd.read_csv("AliceCleaner.txt",delimiter="\t")
# data = df1.values.tolist()

# tokens = word_tokenize(str(data))
# tokens = [w.lower() for w in tokens]

# tokens = list(filter(lambda token: token not in string.punctuation, tokens))

table = str.maketrans('', '', string.punctuation)
stripped = [w.translate(table) for w in tokens]
data = [word for word in stripped if word.isalpha()]
stop_words = set(stopwords.words('english'))
data = [w for w in data if not w in stop_words]

print(tokens)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\nltk\corpus\util.py in __load(self)
#      82                 try:
# ---> 83                     root = nltk.data.find("{}/{}".format(self.subdir, zip_name))
#      84                 except LookupError:
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     582     resource_not_found = "\n%s\n%s\n%s\n" % (sep, msg, sep)
# --> 583     raise LookupError(resource_not_found)
#     584
#
# LookupError:
# **********************************************************************
#   Resource stopwords not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('stopwords')
#
#   For more information see: https://www.nltk.org/data.html
#
# ...

# %%
from pathlib import Path
import string

filepath = Path("CandideFr.txt")
text = filepath.read_text()
text = text.replace(string.punctuation, "")
filepath.write_text(text)
# Out:
# 214090

# %%
df1=pd.read_csv("AliceCleaner.txt",delimiter="\t")
df1=df1.replace(string.punctuation,"",regex=True)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-35-0965df647880> in <module>
#       1 df1=pd.read_csv("AliceCleaner.txt",delimiter="\t")
# ----> 2 df1=df1.replace(string.punctuation,"",regex=True)
#       3
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4522         method="pad",
#    4523     ):
# -> 4524         return super().replace(
#    4525             to_replace=to_replace,
#    4526             value=value,
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6929
#    6930                 elif not is_list_like(value):  # NA -> 0
# -> 6931                     new_data = self._mgr.replace(
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-7fd613c3c7e4> in <module>
# ----> 1 print(list1)
#
# NameError: name 'list1' is not defined

# %%
dataset
# Out:
#                                              CHAPTER I.
# 0                                  Down the Rabbit-Hole
# 1     Alice was beginning to get very tired of sitti...
# 2     bank, and of having nothing to do: once or twi...
# 3     the book her sister was reading, but it had no...
# 4     conversations in it, “and what is the use of a...
# ...                                                 ...
# 2470  and make _their_ eyes bright and eager with ma...
# 2471  perhaps even with the dream of Wonderland of l...
# 2472  would feel with all their simple sorrows, and ...
# 2473  their simple joys, remembering her own child-l...
# 2474                                              days.
#
# [2475 rows x 1 columns]

# %%
from nltk.corpus import stopwords
# nltk.download('stopwords')
from nltk.tokenize import word_tokenize
import string

with open('AliceCleaner.txt','r', encoding="utf8") as f:
    content = f.read()


with open('Stopwords.txt','r', encoding="utf8") as f1:
    stop_words1 = f1.read()

tokens_stop = word_tokenize(stop_words1)

print(string.punctuation) 
tokens = word_tokenize(content)
tokens = list(filter(lambda token: token not in string.punctuation, tokens))

tokens_without_sw = [word for word in tokens if not word in tokens1]



print(tokens_without_sw)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# ...

# %%
with open('AliceCleaner.txt','r', encoding="utf8") as f:
    alice_content = f.read()

with open('AliceInWonderland.txt','r', encoding="utf8") as f:
    alice_content1 = f.read()

with open('CandideEn.txt','r', encoding="utf8") as f:
    candien = f.read()

with open('DonQuijote.txt','r', encoding="utf8") as f:
    don = f.read()

with open('CandideFr.txt','r', encoding="utf8") as f:
    candifr = f.read()

with open('Shakespeare.txt','r', encoding="utf8") as f:
    shake = f.read()












def preprocessing(data):

  with open('Stopwords.txt','r', encoding="utf8") as f1:
      stop_words1 = f1.read()

  tokens_stop = word_tokenize(stop_words1)
  tokens = word_tokenize(data)
  tokens = list(filter(lambda token: token not in string.punctuation, tokens))
  tokens_without_sw = [word for word in tokens if not word in tokens_stop]
  tokens_without_sw = [w.lower() for w in tokens_without_sw]
  
  #table = str.maketrans('', '', string.punctuation)
  #stripped = [w.translate(table) for w in tokens]
  #data = [word for word in stripped if word.isalpha()]
  #stop_words = set(stopwords.words('english'))
  #data = [w for w in data if not w in stop_words]
  print(tokens_without_sw)
  return tokens_without_sw


def test():
